# %%
import sys
import traceback

# %%
from logger.custom_logger import CustomLogger
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from logger.custom_logger import CustomLogger
#
# ModuleNotFoundError: No module named 'logger'

# %%
class DocumentPortalException(Exception):
    """Custom class for exceptions in the document portal."""
    def __init__(self, error_message:str, error_details:sys):
        _,_,exc_tb = error_details.exc_info()
        self.file_name = exc_tb.tb_frame.f_code.co_filename
        self.line_no = exc_tb.tb_lineno
        self.error_message = error_message
        self.traceback_str = ''.join(traceback.format_exception(*error_details.exc_info()))
    
    def __str__(self):
        return f"""
        Error in [{self.file_name}] at line [{self.line_no}]
        Message : {self.error_message}
        {self.traceback_str}
        """
    
    
    
if __name__ == "__main__":
    try:
        a = 1/0
        print(a)
    except Exception as e:
        app_exc =  DocumentPortalException(e, sys)
        raise app_exc
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 25
#      23     except Exception as e:
#      24         app_exc =  DocumentPortalException(e, sys)
# ---> 25         raise app_exc
#      26
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# DocumentPortalException                   Traceback (most recent call last)
# Cell In[2], line 25
#      21         a = 1/0
#      22         print(a)
#      23     except Exception as e:
#      24         app_exc =  DocumentPortalException(e, sys)
# ---> 25         raise app_exc
#      26
#
# DocumentPortalException:
#         Error in [/var/folders/k2/5sm27s7j0rs5pv6sp1qcnk6m0000gp/T/ipykernel_85202/2971400184.py] at line [21]
#         Message : division by zero
#         Traceback (most recent call last):
#   File "/var/folders/k2/5sm27s7j0rs5pv6sp1qcnk6m0000gp/T/ipykernel_85202/2971400184.py", line 21, in <module>
#     a = 1/0
#         ~^~
# ZeroDivisionError: division by zero
