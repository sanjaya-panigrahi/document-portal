# %%
from langchain_groq import ChatGroq

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
load_dotenv()
# Out:
# False

# %%
load_dotenv()
# Out:
# False

# %%
model = ChatGroq(model="groq/compound")

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="groq/compound")

# %%
model.invoke("What is Capital of Australia?").content
# Out:
# 'The capital of Australia is **Canberra**.'

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
load_dotenv()
# Out:
# True

# %%
embedding_models = GoogleGenerativeAIEmbeddings(model="models/embeddings-001")

# %%
embedding_models = GoogleGenerativeAIEmbeddings(model="models/embeddings-001")

# %%
embedding_models = GoogleGenerativeAIEmbeddings(
    model="gemini-embedding-001"
)

# %%
embedding_models.embed_query("What is Capital of Australia?")
# Out:
# [-0.022846665,
#  -0.030530423,
#  0.036731396,
#  -0.03673245,
#  -0.023652472,
#  -0.009906895,
#  -0.0011678847,
#  -0.0029034792,
#  0.0077570095,
#  -0.010409649,
#  -0.0051457845,
#  -0.019042049,
#  0.004666599,
#  0.025185436,
#  0.13583206,
#  0.0021194578,
#  0.012891026,
#  0.0067172414,
#  -0.008327671,
#  -0.016764047,
#  -0.01763863,
#  -0.008417218,
#  0.022391463,
#  -0.014210208,
#  0.015596252,
#  0.008965582,
#  0.00210686,
#  -0.013677353,
#  0.024474595,
#  0.023188045,
#  -0.0006754678,
#  -0.015870009,
#  0.018399075,
#  -0.0054750997,
#  -0.00060791627,
#  -0.017532395,
#  -0.009403079,
#  0.0019916026,
#  0.003916984,
#  0.008856609,
#  0.001052821,
#  -0.042113647,
#  0.007831612,
#  -0.008136534,
#  0.0012202678,
#  -0.0030845492,
#  0.0051716543,
#  -0.026289228,
#  -0.0029988666,
#  0.019734792,
#  -0.022703005,
#  0.010058579,
#  0.00147954,
#  -0.18505886,
#  -0.0064256177,
#  0.0038995796,
#  0.0206921,
#  -0.0194423,
#  -0.0077320314,
#  -0.02093532,
#  -0.0010329668,
#  0.011415422,
#  -0.014795577,
#  -0.035227306,
#  0.012856344,
#  0.026753107,
#  0.0012638977,
#  0.004814431,
#  -0.01294426,
#  -0.008916883,
#  0.04514827,
#  0.021298356,
#  0.0029622251,
#  -0.021281607,
#  0.0034952776,
#  0.014323429,
#  0.014853019,
#  -0.0010319653,
#  -0.038648043,
#  0.0051534283,
#  0.009647661,
#  -0.00024751452,
#  -0.015784837,
#  0.017096967,
#  0.0006465213,
#  -0.013268974,
#  -0.0090553,
#  -0.029768517,
#  -0.010511295,
#  -0.014215636,
#  0.01704747,
#  -0.02735169,
#  0.023033122,
#  -0.0023423014,
#  0.013354306,
#  0.031526867,
#  0.023326641,
#  0.0016972813,
#  0.008909168,
#  0.030108232,
#  0.0020182081,
#  0.00030851047,
#  -0.0017727978,
#  -0.0071181073,
#  -0.009851763,
#  -0.014789446,
#  -0.0014675823,
#  -0.007591995,
#  0.023389997,
#  0.0032401872,
#  0.03337623,
#  0.005653132,
#  -0.009986977,
#  0.025454251,
#  0.0053188717,
#  -0.1475643,
#  -0.017690126,
#  0.012999461,
#  0.004898716,
#  0.0063293525,
#  -0.00438014,
#  -0.0023681363,
#  0.002130724,
#  0.007798229,
#  0.009784519,
#  0.0012635291,
#  -0.031113785,
#  -0.0061493837,
#  0.018089723,
#  0.002219177,
#  -0.009011817,
#  0.0007655709,
#  0.0025952605,
#  -0.0099957725,
#  0.00010044558,
#  -0.012535384,
#  0.020220486,
#  0.012325286,
#  0.01753016,
#  -0.008103997,
#  -0.0108266,
#  0.014740112,
#  0.029738544,
#  0.0038511513,
#  -0.0049911663,
#  -0.0077803647,
#  0.0067302915,
#  0.010621605,
#  0.010300932,
#  -0.006519705,
#  -0.012565596,
#  0.012435704,
#  -0.003930607,
#  -0.002774435,
#  -0.008564715,
#  -0.0020165832,
#  5.8866943e-05,
#  0.006315972,
#  -0.0028055327,
#  -0.0025757917,
#  -0.00722119,
#  -0.004981927,
#  0.0061954116,
#  -0.012263181,
#  0.015550547,
#  -0.012115804,
#  -0.010284363,
#  -0.004133855,
#  -0.0025326035,
#  -0.0038316103,
#  -0.00955309,
#  0.0044415677,
#  0.013570375,
#  -0.00347524,
#  0.013286954,
#  0.00469179,
#  0.011938542,
#  -0.017871955,
#  -0.0040117544,
#  0.004643041,
#  0.016394453,
#  -0.0051637716,
#  -0.0062811733,
#  0.0015060996,
#  -0.0077972137,
#  -0.000909659,
#  0.014190936,
#  -0.0067732246,
#  -0.0060717566,
#  0.0059141624,
#  0.0008022721,
#  0.008893472,
#  -0.010809172,
#  0.010664221,
#  0.017061997,
#  0.004153263,
#  -0.015162983,
#  -0.00414341,
#  0.002785896,
#  0.0050557107,
#  0.0032807866,
#  0.007819232,
#  -0.003426697,
#  0.01640634,
#  -0.011637758,
#  0.0026403018,
#  0.023218703,
#  0.0022016359,
#  -0.0142731285,
#  0.004474503,
#  0.0120027475,
#  0.010937043,
#  0.09469674,
#  0.006735801,
#  0.014038912,
#  0.00022679713,
#  0.0008255245,
#  -0.010558871,
#  0.01245383,
#  -0.015060193,
#  -0.015041259,
#  -0.0032996403,
#  -0.0053685363,
#  0.00047467448,
#  0.011077504,
#  0.0017777843,
#  0.0044064843,
#  -0.008146809,
#  -0.005360532,
#  0.007863863,
#  0.009019491,
#  0.012873003,
#  -0.011613593,
#  -0.002072118,
#  -0.006740741,
#  0.008131345,
#  0.0012489789,
#  0.0011926258,
#  0.017299931,
#  -0.0136418445,
#  0.012688142,
#  -0.006901245,
#  0.017779741,
#  -0.01039734,
#  ...]

# %%
1. Data Ingestion

# %%
from langchain_community.document_loaders import PyPDFLoader
# Out:
# /var/folders/k2/5sm27s7j0rs5pv6sp1qcnk6m0000gp/T/ipykernel_21002/4175148793.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
import os

# %%
file_path = os.path.join(os.getcwd(), "data", "Croma_Operations_Manual_v2.pdf")

# %%
document = PyPDFLoader(file_path).load()

# %%
len(document)
# Out:
# 14

# %%
text_splitter =  RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=150, length_function=len)

# %%
docs = text_splitter.split_documents(document)

# %%
 len(docs)
 len(document)
# Out:
# 14

# %%
docs
# Out:
# [Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 0, 'page_label': '1'}, page_content='Croma - A\nTATA\nEnterprise\nComprehensive\nCustomer\nHandbook\nVersion\n2026.1 -\nOperational\nGuidelines\n& FAQ\nOfficial\nRetail\nPartner\nDigital\nExcellence |\nPage 1'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 1, 'page_label': '2'}, page_content='1. Corporate Profile & Vision\nWho is the parent company behind the brand?\nCroma - A TATA Enterprise is a subsidiary of its respective parent conglomerate,\ndedicated to bringing the latest in technology to the Indian consumer . We aim to\nprovide a seamless omnichannel experience.\nHow many stores do you operate across India?\nCurrently,  we  operate  over  400+  large-format  stores  across  120+  cities  in  India,\nranging from Tier 1 metros to Tier 3 emerging markets.'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 1, 'page_label': '2'}, page_content="Currently,  we  operate  over  400+  large-format  stores  across  120+  cities  in  India,\nranging from Tier 1 metros to Tier 3 emerging markets.\nWhat is the 'Green Electronics' initiative?\nWe are committed to e-waste management. Customers can drop off old electronics at\nour designated 'E-Bins' in-store for responsible recycling.\nPage 2"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 2, 'page_label': '3'}, page_content="2. Pre-Purchase & Store Experience\nCan I book a personalized shopping assistant?\nYes, we offer a 'Personal Shopper' service where an expert is assigned to guide you\nthrough technical specifications based on your home layout and budget.\nAre pets allowed in the stores?\nWhile service animals are always welcome, we generally advise against bringing\npets into the main showroom to ensure the safety of delicate electronic displays.\nDo you offer bulk pricing for corporate gifting?"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 2, 'page_label': '3'}, page_content="pets into the main showroom to ensure the safety of delicate electronic displays.\nDo you offer bulk pricing for corporate gifting?\nYes, we have a dedicated B2B desk for corporate orders, providing tax invoices (GST)\nand volume-based discounts.\nWhat is the 'Experience Zone'?\nOur flagship stores feature live experience zones where you can test gaming rigs,\nhigh-end audio setups, and smart home ecosystems in a real-world environment.\nPage 3"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 3, 'page_label': '4'}, page_content="3. Detailed Product Categories\nWhat brands of smartphones are available?\nWe carry the full range of Apple, Samsung, Google Pixel, OnePlus, Xiaomi, and Vivo\nproducts.\nDo you sell specialized photography equipment?\nOur  'Pro-Photo'  section  includes  DSLRs,  Mirrorless  cameras,  Gimbals,  and  studio\nlighting from Sony, Canon, and Nikon.\nAre custom-built PCs available?\nWhile we sell pre-built gaming towers, we also provide components like GPUs, RAM,\nand SSDs for DIY enthusiasts."),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 3, 'page_label': '4'}, page_content='Are custom-built PCs available?\nWhile we sell pre-built gaming towers, we also provide components like GPUs, RAM,\nand SSDs for DIY enthusiasts.\nWhich home appliances do you specialize in?\nWe offer an extensive range of Air Conditioners, Refrigerators, Washing Machines,\nand Microwaves from brands like LG, Samsung, Whirlpool, and Daikin.\nPage 4'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 4, 'page_label': '5'}, page_content="4. Order & Delivery Logistics\nWhat is 'Express Delivery'?\nFor select pin codes and products, we offer delivery within 3 hours of placing the\norder online.\nHow do I track my heavy appliance delivery?\nOnce your order is dispatched, you receive a real-time tracking link via SMS. Our\nlogistics team will also call 30 minutes prior to arrival.\nDo you deliver to high-rise buildings?\nYes, however , please ensure the elevator is functional for large items like 85-inch TVs"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 4, 'page_label': '5'}, page_content='Do you deliver to high-rise buildings?\nYes, however , please ensure the elevator is functional for large items like 85-inch TVs\nor  double-door  refrigerators.  Manual  lifting  beyond  the  2nd  floor  may  incur  a\nnominal labor charge.\nCan I change my delivery address after ordering?\nAddress changes are possible within 2 hours of order placement, provided the new\naddress is within the same city and service zone.\nPage 5'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 5, 'page_label': '6'}, page_content="5. Installation & Demo Procedures\nIs installation free for all appliances?\nStandard installation is usually free for ACs, TVs, and Washing Machines. However ,\nadditional materials like extra copper piping or wall brackets are charged as per the\nbrand's rate card.\nHow soon will the technician arrive after delivery?\nTechnicians are typically scheduled within 24-48 hours of delivery. You will receive\nan OTP-based service request via the brand's official portal.\nWhat is covered in a standard demo?"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 5, 'page_label': '6'}, page_content="an OTP-based service request via the brand's official portal.\nWhat is covered in a standard demo?\nThe technician will explain the primary features, connectivity options, maintenance\ntips, and safety precautions for the appliance.\nPage 6"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 6, 'page_label': '7'}, page_content="6. Comprehensive Payment FAQ\nDo you accept international credit cards?\nWe  accept  international  Visa  and  Mastercard,  but  they  must  be  enabled  for  '3D\nSecure' transactions. Currency conversion rates apply as per your bank.\nCan I split payment between two different cards?\nYes, in-store customers can split the total invoice value across multiple payment\nmodes (e.g., half cash, half card).\nHow does the 'Buy Now, Pay Later' (BNPL) scheme work?"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 6, 'page_label': '7'}, page_content="modes (e.g., half cash, half card).\nHow does the 'Buy Now, Pay Later' (BNPL) scheme work?\nWe  partner  with  ZestMoney  and  LazyPay  to  offer  instant  credit  at  checkout  for\neligible customers.\nIs GST invoicing available for business customers?\nYes, please provide your GSTIN at the time of billing to avail of input tax credit.\nPage 7"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 7, 'page_label': '8'}, page_content="7. Returns, Replacements & Dead-on-Arrival\n(DOA)\nWhat defines a DOA (Dead on Arrival) product?\nA product that fails to power on or shows a functional defect within the first 24-48\nhours is classified as DOA.\nWhy can't I return an iPhone once the seal is broken?\nAs per Apple's global policy, once the activation is triggered, the warranty begins.\nAny issues post-activation must be handled by Apple Authorized Service Centers.\nCan I return a product if I don't like the color?"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 7, 'page_label': '8'}, page_content="Any issues post-activation must be handled by Apple Authorized Service Centers.\nCan I return a product if I don't like the color?\nWe generally do not accept returns for 'change of mind' once the box is opened. We\nencourage customers to view the units in-store before purchase.\nWhat is the process for returning a defective large appliance?\nAn authorized brand technician must visit and issue a 'Job Sheet' confirming the\ndefect. Once we receive this report, we initiate a replacement.\nPage 8"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 8, 'page_label': '9'}, page_content="8. Extended Warranty & Protection Plans\nWhat is the 'ZipCare' or 'Device Care' plan?\nThese  are  our  proprietary  extended  warranty  plans  that  cover  mechanical  and\nelectrical breakdowns after the manufacturer's warranty expires.\nDoes the plan cover accidental liquid damage?\nStandard extended warranties do not. However , we offer premium 'Accidental &\nLiquid Protection' (ALP) plans for smartphones and laptops.\nIs the protection plan transferable?"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 8, 'page_label': '9'}, page_content="Liquid Protection' (ALP) plans for smartphones and laptops.\nIs the protection plan transferable?\nYes, if you sell the device, the plan can be transferred to the new owner , adding to\nthe resale value.\nPage 9"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 9, 'page_label': '10'}, page_content='9. Loyalty Programs & Gift Cards\nHow do I earn loyalty points?\nEvery purchase earns you reward points linked to your mobile number . These can\nbe redeemed as a discount on your next purchase.\nDo gift cards have an expiry date?\nOur physical and e-gift cards are typically valid for 12 months from the date of\nissuance.\nCan I use multiple gift cards for a single purchase?\nYes, you can stack up to 5 gift cards for a single high-value transaction.\nPage 10'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 10, 'page_label': '11'}, page_content="10. Troubleshooting & Basic Technical\nSupport\nMy new TV has a 'No Signal' error . What should I do?\nCheck if the HDMI source matches the port used. Often, a simple restart of the Set-\nTop Box resolves this.\nMy refrigerator is making a humming sound.\nModern inverter compressors vary their speed, causing a slight hum. If the sound is\nexcessive or clicking, please contact our support.\nWhy is my laptop battery draining fast?"),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 10, 'page_label': '11'}, page_content='excessive or clicking, please contact our support.\nWhy is my laptop battery draining fast?\nHigh-performance  settings  and  background  apps  often  drain  batteries.  We\nrecommend running a battery health check via our in-store tech desk.\nPage 11'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 11, 'page_label': '12'}, page_content='11. Ethical Sourcing & Sustainability\nWhere do you source your products from?\nWe source directly from authorized brand distributors and manufacturers to ensure\n100% genuine products.\nWhat is your policy on plastic-free packaging?\nWe are actively transitioning to biodegradable bubble wrap and recycled cardboard\nfor all home deliveries.\nPage 12'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 12, 'page_label': '13'}, page_content='12. Legal & Privacy Policies\nHow do you protect my personal data?\nWe comply with the Digital Personal Data Protection Act. Your data is encrypted and\nused only for order processing and service updates.\nWhat are the terms of service for the mobile app?\nThe app usage is governed by our end-user license agreement, which ensures a safe\nshopping environment.\nPage 13'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 13, 'page_label': '14'}, page_content='Appendix: Terms & Conditions Reference\nThis document serves as a comprehensive guide to our retail operations. All policies\nmentioned herein are subject to change without prior notice. For the most updated legal\nterms, please visit our official website footer under "Terms of Use". Our goal is to ensure\n100% customer satisfaction through transparency and efficiency.\nNote: Regional variations may apply to certain promotions and delivery timelines.'),
#  Document(metadata={'producer': 'WeasyPrint 62.3', 'creator': 'PyPDF', 'creationdate': '', 'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf', 'total_pages': 14, 'page': 13, 'page_label': '14'}, page_content='100% customer satisfaction through transparency and efficiency.\nNote: Regional variations may apply to certain promotions and delivery timelines.\nCertain rural areas may have extended delivery windows up to 10 business days.\n-- End of Document Section --\nPage 14')]

# %%
docs[1].metadata
# Out:
# {'producer': 'WeasyPrint 62.3',
#  'creator': 'PyPDF',
#  'creationdate': '',
#  'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf',
#  'total_pages': 14,
#  'page': 1,
#  'page_label': '2'}

# %%
docs[4].metadata
# Out:
# {'producer': 'WeasyPrint 62.3',
#  'creator': 'PyPDF',
#  'creationdate': '',
#  'source': '/Users/sanjaya-panigrahi/Projects/JOB PREP/Repos/document-portal/notebook/data/Croma_Operations_Manual_v2.pdf',
#  'total_pages': 14,
#  'page': 2,
#  'page_label': '3'}
